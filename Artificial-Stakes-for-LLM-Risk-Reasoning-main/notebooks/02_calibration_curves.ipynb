# %% [markdown]
# # 02 - Calibration Curves
#
# Plot reliability diagrams and compute ECE / Brier scores for each condition x dataset x model cell. Use this to test H1: persistent stakes improve calibration.

# %%
from risk_reasoning.eval import ece, brier_score, reliability_curve  # noqa: F401
