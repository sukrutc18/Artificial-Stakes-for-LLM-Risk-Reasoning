# %% [markdown]
# # 03 - Sequential Trajectories
#
# Plot budget trajectories over episode steps, cumulative regret, recovery rate, and mistake propagation under the four conditions.

# %%
from risk_reasoning.eval import cumulative_regret, mistake_propagation  # noqa: F401
