# %% [markdown]
# # 04 - Final Figures
#
# Produce the publication-ready figures and tables for the May 7 writeup: main accuracy table, calibration summary, sequential regret plot, and reasoning-proxy comparisons.

# %%
import matplotlib.pyplot as plt  # noqa: F401
import pandas as pd  # noqa: F401
