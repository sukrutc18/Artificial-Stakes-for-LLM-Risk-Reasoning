# %% [markdown]
# # 01 - Dataset EDA
#
# Exploratory looks at the synthetic EV generator, ConvFinQA, ARC-Challenge, MedQA, and the sequential budget env. Sanity-check distributions, answer balance, prompt lengths, and coverage of problem families.

# %%
from risk_reasoning.data import Question  # noqa: F401
